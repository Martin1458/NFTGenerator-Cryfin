# %%
root_file = "G:/Sdílené disky/bitterfly_disk/NFTs, hry, metaverse/NFT kolekce (1)/Testovací kolekce/NFTImgGenerator15/"
print(root_file)
# Out:
# G:/Sdílené disky/bitterfly_disk/NFTs, hry, metaverse/NFT kolekce (1)/Testovací kolekce/NFTImgGenerator15/

# %%
root_file + "Parts"
# Out:
# 'G:/Sdílené disky/bitterfly_disk/NFTs, hry, metaverse/NFT kolekce (1)/Testovací kolekce/NFTImgGenerator15/Parts'
